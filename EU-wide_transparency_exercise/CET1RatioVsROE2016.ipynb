# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label, HoverTool

# %% [markdown]
# # Data

# %%
#read EBA data regarding capital
df = pd.read_csv('https://www.eba.europa.eu/documents/10180/2027702/tr_oth.csv', encoding='latin1',\
                 usecols=['LEI_Code','Period','Label','Amount'])

# %%
#read EBA metadata
metadata_banks= pd.read_excel('https://www.eba.europa.eu/documents/10180/2027702/TR_Metadata.xlsx',\
                              sheetname='Bank list', skiprows=1, usecols=['LEI_Code','Name','Desc_country'])

# %%
#prepare CET1 ratio, CET1, Profit/Loss
df_CET1_ratio_fl=df[(df['Label']=='COMMON EQUITY TIER 1 CAPITAL RATIO (transitional period)') & \
                    (df['Period']==201612)][['LEI_Code','Amount']]
df_CET1_ratio_fl.columns=['LEI_Code', 'CET1_ratio_transitional_period']


df_CET1=df[(df['Label']=='COMMON EQUITY TIER 1 CAPITAL (net of deductions and after applying transitional adjustments)') & \
                    (df['Period']==201612)][['LEI_Code','Amount']]
df_CET1.columns=['LEI_Code', 'CET1']


df_profit_loss=df[(df['Label']=='PROFIT OR (-) LOSS BEFORE TAX FROM CONTINUING OPERATIONS') & \
                    (df['Period']==201612)][['LEI_Code','Amount']]
df_profit_loss.columns=['LEI_Code', 'profit_loss']

# %%
#merge individual df
df=df_CET1_ratio_fl.merge(df_CET1, left_on='LEI_Code', right_on='LEI_Code', how='outer').merge\
(df_profit_loss, left_on='LEI_Code', right_on='LEI_Code', how='outer').merge\
(metadata_banks, left_on='LEI_Code', right_on='LEI_Code', how='inner')

# %%
#remove NA
df=df.dropna()

# %%
#calculate ROE
df['ROE'] = df['profit_loss']/df['CET1']

# %% [markdown]
# # Chart

# %%
source=ColumnDataSource (data=dict(height=df['CET1_ratio_transitional_period'],
                                   weight=df['ROE'],
                                   names=df['Name']
                                  ))
hover=HoverTool(tooltips=
                    [("ROE","@weight"),
                    ("CET1 Ratio","@height"),
                    ("Bank", "@names")]
               )

TITLE="Return on Common Equity and CET1 Ratio as of Dec 2016 (source: EBA)"

p=figure(plot_width=500, plot_height=250, responsive=True, tools=['pan','wheel_zoom','box_zoom', 'reset', hover], title=TITLE,
        logo=None)

p.scatter(x='weight', y='height',  source=source, alpha=0.2)

p.xaxis.axis_label="Return on Common Equity (CET1)"
p.yaxis.axis_label="CET1 Capital Ratio"

labels=LabelSet(x='weight', y='height', text='names', level='glyph', x_offset=5, y_offset=0, text_font_size="6pt", source=source)
label_opts=dict(x=0, y=1, x_units='screen', y_units='screen')

#msg1="---"
#caption1=Label(text=msg1, **label_opts)

p.add_layout(labels)
#p.add_layout(caption1, 'below')

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d65f6148-938f-4122-81e4-3bc771f68b9f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d048fc8b-c84a-460a-a8be-7a49bdcdb838"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d048fc8b-c84a-460a-a8be-7a49bdcdb838");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d048fc8b-c84a-460a-a8be-7a49bdcdb838");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd048fc8b-c84a-460a-a8be-7a49bdcdb838' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fcff708b-b75a-435b-89a0-a299549a1b2b":{"roots":{"references":[{"attributes":{"data_source":{"id":"8f4781a9-e358-4374-b586-e72f17a0f572","type":"ColumnDataSource"},"glyph":{"id":"9ef252c6-bc5f-4e26-bc87-f3ee96169ee1","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"98d3bb58-fbc4-4ac4-a5e1-e73a83fdabd6","type":"Circle"},"selection_glyph":null},"id":"240e14df-a3b2-4ca4-af31-3758b7ab0e60","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"7730626f-1ff4-4075-8c40-6f4050181cba","subtype":"Figure","type":"Plot"},"tooltips":[["ROE","@weight"],["CET1 Ratio","@height"],["Bank","@names"]]},"id":"3587bfc8-5531-42f8-ad55-18c9e3c0ec54","type":"HoverTool"},{"attributes":{},"id":"44a9e9d8-7030-49d2-a89c-11781d8758ff","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["height","weight","names"],"data":{"height":{"__ndarray__":"...","dtype":"float64","shape":[119]},"names":["DekaBank Deutsche Girozentrale","VTB Bank (Austria) AG","Caixa Econ\u00f3mica Montepio Geral","The Royal Bank of Scotland Group Public Limited Company","MeDirect Group Limited","KBC Group NV","Biser Topco S.a.r.l.","Intesa Sanpaolo SpA","Erwerbsgesellschaft der S-Finanzgruppe mbH & Co. KG","Jyske Bank","Allied Irish Banks, Plc","NRW.Bank ","Promontoria Sacher Holding N.V.","Alpha Bank AE","N.V. Bank Nederlandse Gemeenten","Caixa Central de Cr\u00e9dito Agr\u00edcola M\u00fatuo, CRL","Kuntarahoitus Oyj","Deutsche Zentral-Genossenschaftsbank AG","Sberbank Europe AG","AS LHV Group","HASPA Finanzholding AG","HSH Beteiligungs Management GmbH","Bank of Valletta Plc","RAIFFEISEN-HOLDING NIEDER\u00d6STERREICH-WIEN registrierte Genossenschaft mit beschr\u00e4nkter Haftung","State Street Europe Holdings Germany S.a.r.l. & Co. KG","OTP Bank Nyrt.","Raiffeisenbankengruppe O\u00d6 Verbund eGen","Landwirtschaftliche Rentenbank","NOVA LJUBLJANSKA BANKA D.D., LJUBLJANA","Abanka d.d.","Banco Santander SA","Co -operative Central Bank  Ltd ","Unicaja Banco S.A.","Investar","Novo Banco","Precision Capital S.A.","L\u00e4nsf\u00f6rs\u00e4kringar Bank AB - group","DNB Bank ASA","BFA Tenedora de Acciones, S.A.U.","SFIL (Soci\u00e9t\u00e9 de Financement Local)","ABLV Bank","RBC Investor Services Bank S.A.","Citibank Holdings Ireland Limited","ING Groep N.V.","Ibercaja Banco","Lloyds Banking Group Plc","Banco Mare Nostrum","SpareBank 1 SR-Bank ASA\u00a0","Banca Transilvania","UniCredit SpA","Kutxabank","First Investment Bank","Nationwide Building Society","National Bank of Greece SA","Permanent TSB Group Holdings Plc","Bank of Cyprus Holdings Public Limited Company","Liberbank","Nordea Bank - group","ABN AMRO Group N.V.","de Volksholding B.V. ","OP Financial group","Deutsche Bank AG","SpareBank 1 SMN","Unione di Banche Italiane SCpA","Credito Emiliano Holding SpA","Commerzbank AG","Banco de Cr\u00e9dito Social Cooperativo SA\u2019","ABANCA Holding Financiero","Criteria Caixa S.A.U.","RCI banque (Renault Cr\u00e9dit International)","Cr\u00e9dit Mutuel Group","La Banque Postale","Bpifrance (Banque Publique d\u2019Investissement)","Belfius Banque SA","Volksbanken Verbund","Landesbank Baden-W\u00fcrttemberg","Hellenic Bank Public Company Ltd","Dexia NV","Co\u00f6peratieve Rabobank U.A.","Landesbank Hessen-Th\u00fcringen Girozentrale","Norddeutsche Landesbank Girozentrale ","Deutsche Pfandbriefbank AG","Kommuninvest - group","Aareal Bank AG","Banca Carige SpA - Cassa di Risparmio di Genova e Imperia","Skandinaviska Enskilda Banken - group","Groupe BPCE","Groupe Cr\u00e9dit Agricole","Barclays Plc","Sydbank","SBAB Bank AB - group","DEPFA BANK Plc","Banca Popolare di Sondrio","Banca Monte dei Paschi di Siena SpA","Eurobank Ergasias SA","Banco Comercial Portugu\u00eas SA","Banco Bilbao Vizcaya Argentaria, SA","Nykredit Realkredit","AXA Bank Belgium SA","Swedbank - group","Piraeus Bank SA","Danske Bank","HSBC Holdings Plc","Bank of New York Mellon","BPER Banca S.p.A. ","Svenska Handelsbanken - group","I ...
